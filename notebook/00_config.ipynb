# %%
# --- 1. CREDENCIALES DIRECTAS ---
# Decidí usar variables estáticas para evitar el bug de pérdida de contexto 
# de los widgets en Databricks Community Edition durante la ingesta.
ACCESS_KEY = "AKIAVY2PG73H5W3CC2O7"
SECRET_KEY = "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"
BUCKET_NAME = "cloudcamp-hire-vehicle-trip-records"

# --- 2. NOMBRES DE TABLAS ---
BRONCE_TAXI_TABLE = "nyc_taxi_2025_enero"
BRONCE_ZONES_TABLE = "bronze_taxi_zones"
SILVER_TAXI_TABLE = "silver_nyc_taxi"
GOLD_KPI_TABLE = "gold_taxi_kpis"

print("✅ Configuración estática cargada.")
